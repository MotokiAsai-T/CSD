# %%
from main import main 
import time

if __name__ == "__main__":
    # start_time = time.time()
    main()
    # end_time = time.time()
    # print("run time:", end_time - start_time, "seconds")
# Out:
# Converged in 176 iterations.
# v*: [ 0.762   0.2518  1.3047  0.065   1.542   1.2218  2.0315  2.1489  1.9264
#   1.7125  1.0704  1.2317  1.0199  0.3392  1.2406  0.2746  1.7717  1.7208
#   0.1001  1.8983  1.6833  0.9819  0.8575 -0.0334  0.6964]
# Time: 83.712 seconds
# y_rs:
# [0.7583 0.8454 0.7423 0.8746 0.6469 0.7214 0.505  0.4425 0.4559 0.5575
#  0.6925 0.6732 0.687  0.8016 0.7215 0.8603 0.5608 0.5421 0.8863 0.5616
#  0.6059 0.7112 0.7565 0.8805 0.7504]
# z_rs_1:
# [0.7583 0.8454 0.7423 0.8746 0.6469 0.7214 0.505  0.4425 0.4559 0.5575
#  0.6925 0.6732 0.687  0.8016 0.7215 0.8603 0.5608 0.5421 0.8863 0.5616
#  0.6059 0.7112 0.7565 0.8805 0.7504]
