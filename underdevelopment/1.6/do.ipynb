# %%
from main import main 
import time
from datetime import datetime
import numpy as np

times = 10
time_list = np.zeros(times)
start__time = datetime.now()
print("開始時刻:", start__time)
for i in range(times):
    if __name__ == "__main__":        
        print(i+1,"回目:")
        time_list[i] = main()
        print("\n")
        i += 1

print("time_list:", time_list)
print("average time:", sum(time_list)/times)
print("Max time:", max(time_list))
print("min time:", min(time_list))

print()
end__time = datetime.now()
print("終了時間:", end__time)
print("全体実行時間:", end__time - start__time)
# Out:
# 開始時刻: 2025-01-06 16:12:29.891410
# 1 回目:
# Converged in 213 iterations.
# Time: 190.344 seconds
#
#
# 2 回目:
# Converged in 206 iterations.
# Time: 183.364 seconds
#
#
# 3 回目:
# Converged in 206 iterations.
# Time: 183.167 seconds
#
#
# 4 回目:
# Converged in 205 iterations.
# Time: 185.552 seconds
#
#
# 5 回目:
# Converged in 208 iterations.
# Time: 185.439 seconds
#
#
# 6 回目:
# Converged in 215 iterations.
# Time: 187.798 seconds
#
#
# 7 回目:
# Converged in 204 iterations.
# Time: 177.849 seconds
#
#
# 8 回目:
# Converged in 208 iterations.
# Time: 181.325 seconds
#
#
# 9 回目:
# Converged in 205 iterations.
# Time: 178.253 seconds
#
#
# 10 回目:
# Converged in 209 iterations.
# Time: 180.77 seconds
#
#
# time_list: [190.34352922 183.36370683 183.16722894 185.55187011 185.4386065
#  187.79764414 177.84873843 181.3249805  178.25314879 180.77005053]
# average time: 183.38595039844512
# Max time: 190.34352922439575
# min time: 177.84873843193054
#
# 終了時間: 2025-01-06 16:43:03.818705
# 全体実行時間: 0:30:33.927295
