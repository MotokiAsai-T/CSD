# %%
from main_co import main_co
from main import main 
import time
from datetime import datetime
import numpy as np

print("MCA from MCAmo:")
times = 10
time_list = np.zeros(times)
start__time = datetime.now()
print("開始時刻:", start__time)
for i in range(times):
    if __name__ == "__main__":        
        print(i+1,"回目:")
        time_list[i] = main_co()
        print("\n")
        i += 1

print("time_list:", time_list)
print("average time:", sum(time_list)/times)
print("Max time:", max(time_list))
print("min time:", min(time_list))

print()
end__time = datetime.now()
print("終了時間:", end__time)
print("全体実行時間:", end__time - start__time)

print("="*100)

print("calculate_MC:")
times = 10
time_list = np.zeros(times)
start__time = datetime.now()
print("開始時刻:", start__time)
for i in range(times):
    if __name__ == "__main__":        
        print(i+1,"回目:")
        time_list[i] = main()
        print("\n")
        i += 1

print("time_list:", time_list)
print("average time:", sum(time_list)/times)
print("Max time:", max(time_list))
print("min time:", min(time_list))

print()
end__time = datetime.now()
print("終了時間:", end__time)
print("全体実行時間:", end__time - start__time)
# Out:
# MCA from MCAmo:
# 開始時刻: 2025-01-17 14:46:51.845022
# 1 回目:
# Converged in 741 iterations.
# Time: 18.914 seconds
#
#
# 2 回目:
# Converged in 438 iterations.
# Time: 11.11 seconds
#
#
# 3 回目:
# Converged in 771 iterations.
# Time: 19.517 seconds
#
#
# 4 回目:
# Converged in 855 iterations.
# Time: 21.646 seconds
#
#
# 5 回目:
# Converged in 582 iterations.
# Time: 14.846 seconds
#
#
# 6 回目:
# Converged in 844 iterations.
# Time: 21.393 seconds
#
#
# 7 回目:
# Converged in 668 iterations.
# Time: 16.896 seconds
#
#
# 8 回目:
# Converged in 848 iterations.
# Time: 21.599 seconds
#
#
# 9 回目:
# Converged in 906 iterations.
# Time: 23.158 seconds
#
#
# 10 回目:
# Converged in 740 iterations.
# Time: 18.767 seconds
#
#
# time_list: [18.91431379 11.11025214 19.51662183 21.64576864 14.84644008 21.39282751
#  16.8961339  21.59926057 23.15795875 18.76652122]
# average time: 18.784609842300416
# Max time: 23.15795874595642
# min time: 11.110252141952515
#
# 終了時間: 2025-01-17 14:49:59.691121
# 全体実行時間: 0:03:07.846099
# ====================================================================================================
# calculate_MC:
# 開始時刻: 2025-01-17 14:49:59.691121
# 1 回目:
# Converged in 616 iterations.
# Time: 7.254 seconds
#
#
# 2 回目:
# Converged in 654 iterations.
# Time: 7.632 seconds
#
#
# 3 回目:
# Converged in 764 iterations.
# Time: 8.763 seconds
#
#
# 4 回目:
# Converged in 816 iterations.
# Time: 9.357 seconds
#
#
# 5 回目:
# Converged in 751 iterations.
# Time: 8.514 seconds
#
#
# 6 回目:
# Converged in 898 iterations.
# Time: 10.352 seconds
#
#
# 7 回目:
# Converged in 724 iterations.
# Time: 8.299 seconds
#
#
# 8 回目:
# Converged in 678 iterations.
# Time: 7.853 seconds
#
#
# 9 回目:
# Converged in 591 iterations.
# Time: 6.847 seconds
#
#
# 10 回目:
# Converged in 553 iterations.
# Time: 6.465 seconds
#
#
# time_list: [ 7.25387478  7.63182116  8.76291919  9.3573103   8.51400566 10.35168624
#   8.29919243  7.8532362   6.84714317  6.46510935]
# average time: 8.133629846572877
# Max time: 10.351686239242554
# min time: 6.465109348297119
#
# 終了時間: 2025-01-17 14:51:21.029415
# 全体実行時間: 0:01:21.338294
