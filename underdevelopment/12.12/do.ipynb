# %%
from main import main 
import time

if __name__ == "__main__":
    start_time = time.time()
    main()
    end_time = time.time()
    print("run time:", end_time - start_time, "seconds")
# Out:
# MC -139.29402502063448
# grad [-4.50710265 -5.24307842 -6.24980358]
# L 1.0
# MC -56.93529963283788
# grad [-10.39746041  -3.63697654  -1.96186855]
# L 1.4641000000000006
# MC -5.28234886756389
# grad [ 0.60800583 -6.15986188 -9.77058867]
# L 1.4641000000000006
# MC 65.86000691987401
# grad [-1.10483549  0.2429561   0.95435163]
# L 1.4641000000000006
# MC 66.81044741390544
# grad [0.09700629 0.05789565 0.91467133]
# L 1.4641000000000006
# MC 67.51106475457998
# grad [ 0.0039328  -0.00696156  0.80613801]
# L 1.4641000000000006
# MC 68.10713826774249
# grad [-0.02228584 -0.03373073  0.52957149]
# L 1.4641000000000006
# MC 68.32599588075541
# grad [-0.02178371 -0.04217766  0.00655228]
# L 1.4641000000000006
# MC 68.30155890227655
# grad [-0.00305711 -0.00488717 -0.25025848]
# L 1.4641000000000006
# MC 68.32610724733081
# grad [ 0.00441839  0.01259606 -0.04344961]
# L 1.4641000000000006
# MC 68.32709784772149
# grad [ 0.00189117  0.00415727 -0.00340158]
# L 1.4641000000000006
# Converged in 11 iterations.
# Optimal v: [0.41870647 0.37459082 0.34982613]
# run time: 0.14109516143798828 seconds
